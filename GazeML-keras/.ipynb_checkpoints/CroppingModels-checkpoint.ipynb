# %% [markdown]
# # Cropping Models
#
# https://github.com/shaoanlu/GazeML-keras

# %%
import pandas as pd
import os
import io 
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
from detector.face_detector import MTCNNFaceDetector
import tensorflow as tf
#from keras import backend as K
# Out:
# <function Network.conv at 0x7f09ffc3f940>
# <function Network.prelu at 0x7f09ffc3fc10>
# <function Network.max_pool at 0x7f09ffc3fe50>
# <function Network.fc at 0x7f09feea50d0>
# <function Network.softmax at 0x7f09feea5310>

# %%
ls mtcnn_weights/
# Out:
# det1.npy  det2.npy  det3.npy  README.md

# %%
mtcnn_weights_dir = "./mtcnn_weights/"
MTCNNFaceDetector(sess=tf.compat.v1.keras.backend.get_session(), model_path=mtcnn_weights_dir)
# Out:
# Tensor("input:0", shape=(None, None, None, 3), dtype=float32) --input conv
# Tensor("conv1/BiasAdd:0", shape=(None, None, None, 10), dtype=float32) ---out conv
# {'data': <tf.Tensor 'input:0' shape=(None, None, None, 3) dtype=float32>, 'conv1': <tf.Tensor 'conv1/BiasAdd:0' shape=(None, None, None, 10) dtype=float32>} --after
# ----layer_decorated----
# Tensor("conv1/BiasAdd:0", shape=(None, None, None, 10), dtype=float32) ---input prelu
# Tensor("PReLU1/add:0", shape=(None, None, None, 10), dtype=float32) ---out prelu
# {'data': <tf.Tensor 'input:0' shape=(None, None, None, 3) dtype=float32>, 'conv1': <tf.Tensor 'conv1/BiasAdd:0' shape=(None, None, None, 10) dtype=float32>, 'PReLU1': <tf.Tensor 'PReLU1/add:0' shape=(None, None, None, 10) dtype=float32>} --after
# ----layer_decorated----
# Tensor("PReLU1/add:0", shape=(None, None, None, 10), dtype=float32) ---input maxpool
# Tensor("pool1:0", shape=(None, None, None, 10), dtype=float32) ---out maxpool
# {'data': <tf.Tensor 'input:0' shape=(None, None, None, 3) dtype=float32>, 'conv1': <tf.Tensor 'conv1/BiasAdd:0' shape=(None, None, None, 10) dtype=float32>, 'PReLU1': <tf.Tensor 'PReLU1/add:0' shape=(None, None, None, 10) dtype=float32>, 'pool1': <tf.Tensor 'pool1:0' shape=(None, None, None, 10) dtype=float32>} --after
# ----layer_decorated----
# Tensor("pool1:0", shape=(None, None, None, 10), dtype=float32) --input conv
# Tensor("conv2/BiasAdd:0", shape=(None, None, None, 16), dtype=float32) ---out conv
# {'data': <tf.Tensor 'input:0' shape=(None, None, None, 3) dtype=float32>, 'conv1': <tf.Tensor 'conv1/BiasAdd:0' shape=(None, None, None, 10) dtype=float32>, 'PReLU1': <tf.Tensor 'PReLU1/add:0' shape=(None, None, None, 10) dtype=float32>, 'pool1': <tf.Tensor 'pool1:0' shape=(None, None, None, 10) dtype=float32>, 'conv2': <tf.Tensor 'conv2/BiasAdd:0' shape=(None, None, None, 16) dtype=float32>} --after
# ----layer_decorated----
# Tensor("conv2/BiasAdd:0", shape=(None, None, None, 16), dtype=float32) ---input prelu
# Tensor("PReLU2/add:0", shape=(None, None, None, 16), dtype=float32) ---out prelu
# {'data': <tf.Tensor 'input:0' shape=(None, None, None, 3) dtype=float32>, 'conv1': <tf.Tensor 'conv1/BiasAdd:0' shape=(None, None, None, 10) dtype=float32>, 'PReLU1': <tf.Tensor 'PReLU1/add:0' shape=(None, None, None, 10) dtype=float32>, 'pool1': <tf.Tensor 'pool1:0' shape=(None, None, None, 10) dtype=float32>, 'conv2': <tf.Tensor 'conv2/BiasAdd:0' shape=(None, None, None, 16) dtype=float32>, 'PReLU2': <tf.Tensor 'PReLU2/add:0' shape=(None, None, None, 16) dtype=float32>} --after
# ----layer_decorated----
# Tensor("PReLU2/add:0", shape=(None, None, None, 16), dtype=float32) --input conv
# Tensor("conv3/BiasAdd:0", shape=(None, None, None, 32), dtype=float32) ---out conv
# {'data': <tf.Tensor 'input:0' shape=(None, None, None, 3) dtype=float32>, 'conv1': <tf.Tensor 'conv1/BiasAdd:0' shape=(None, None, None, 10) dtype=float32>, 'PReLU1': <tf.Tensor 'PReLU1/add:0' shape=(None, None, None, 10) dtype=float32>, 'pool1': <tf.Tensor 'pool1:0' shape=(None, None, None, 10) dtype=float32>, 'conv2': <tf.Tensor 'conv2/BiasAdd:0' shape=(None, None, None, 16) dtype=float32>, 'PReLU2': <tf.Tensor 'PReLU2/add:0' shape=(None, None, None, 16) dtype=float32>, 'conv3': <tf.Tensor 'conv3/BiasAdd:0' shape=(None, None, None, 32) dtype=float32>} --after
# ----layer_decorated----
# Tensor("conv3/BiasAdd:0", shape=(None, None, None, 32), dtype=float32) ---input prelu
# Tensor("PReLU3/add:0", shape=(None, None, None, 32), dtype=float32) ---out prelu
# {'data': <tf.Tensor 'input:0' shape=(None, None, None, 3) dtype=float32>, 'conv1': <tf.Tensor 'conv1/BiasAdd:0' shape=(None, None, None, 10) dtype=float32>, 'PReLU1': <tf.Tensor 'PReLU1/add:0' shape=(None, None, None, 10) dtype=float32>, 'pool1': <tf.Tensor 'pool1:0' shape=(None, None, None, 10) dtype=float32>, 'conv2': <tf.Tensor 'conv2/BiasAdd:0' shape=(None, None, None, 16) dtype=float32>, 'PReLU2': <tf.Tensor 'PReLU2/add:0' shape=(None, None, None, 16) dtype=float32>, 'conv3': <tf.Tensor 'conv3/BiasAdd:0' shape=(None, None, None, 32) dtype=float32>, 'PReLU3': <tf.Tensor 'PReLU3/add:0' shape=(None, None, None, 32) dtype=float32>} --after
# ----layer_decorated----
# Tensor("PReLU3/add:0", shape=(None, None, None, 32), dtype=float32) --input conv
# Tensor("conv4-1/BiasAdd:0", shape=(None, None, None, 2), dtype=float32) ---out conv
# {'data': <tf.Tensor 'input:0' shape=(None, None, None, 3) dtype=float32>, 'conv1': <tf.Tensor 'conv1/BiasAdd:0' shape=(None, None, None, 10) dtype=float32>, 'PReLU1': <tf.Tensor 'PReLU1/add:0' shape=(None, None, None, 10) dtype=float32>, 'pool1': <tf.Tensor 'pool1:0' shape=(None, None, None, 10) dtype=float32>, 'conv2': <tf.Tensor 'conv2/BiasAdd:0' shape=(None, None, None, 16) dtype=float32>, 'PReLU2': <tf.Tensor 'PReLU2/add:0' shape=(None, None, None, 16) dtype=float32>, 'conv3': <tf.Tensor 'conv3/BiasAdd:0' shape=(None, None, None, 32) dtype=float32>, 'PReLU3': <tf.Tensor 'PReLU3/add:0' shape=(None, None, None, 32) dtype=float32>, 'conv4-1': <tf.Tensor 'conv4-1/BiasAdd:0' shape=(None, None, None, 2) dtype=float32>} --after
# ----layer_decorated----
# Tensor("conv4-1/BiasAdd:0", shape=(None, None, None, 2), dtype=float32) ---target softmax
# WARNING:tensorflow:From /home/khaldoun/Desktop/TOV_DataAcquisition/GazeML-keras/mtcnn_detect_face.py:242: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Tensor("prob1:0", shape=(None, None, None, 2), dtype=float32) ---out softmax
# {'data': <tf.Tensor 'input:0' shape=(None, None, None, 3) dtype=float32>, 'conv1': <tf.Tensor 'conv1/BiasAdd:0' shape=(None, None, None, 10) dtype=float32>, 'PReLU1': <tf.Tensor 'PReLU1/add:0' shape=(None, None, None, 10) dtype=float32>, 'pool1': <tf.Tensor 'pool1:0' shape=(None, None, None, 10) dtype=float32>, 'conv2': <tf.Tensor 'conv2/BiasAdd:0' shape=(None, None, None, 16) dtype=float32>, 'PReLU2': <tf.Tensor 'PReLU2/add:0' shape=(None, None, None, 16) dtype=float32>, 'conv3': <tf.Tensor 'conv3/BiasAdd:0' shape=(None, None, None, 32) dtype=float32>, 'PReLU3': <tf.Tensor 'PReLU3/add:0' shape=(None, None, None, 32) dtype=float32>, 'conv4-1': <tf.Tensor 'conv4-1/BiasAdd:0' shape=(None, None, None, 2) dtype=float32>, 'prob1': <tf.Tensor 'prob1:0' shape=(None, None, None, 2) dtype=float32>} --after
# ----layer_decorated----
# Tensor("PReLU3/add:0", shape=(None, None, None, 32), dtype=float32) --input conv
# Tensor("conv4-2/BiasAdd:0", shape=(None, None, None, 4), dtype=float32) ---out conv
# {'data': <tf.Tensor 'input:0' shape=(None, None, None, 3) dtype=float32>, 'conv1': <tf.Tensor 'conv1/BiasAdd:0' shape=(None, None, None, 10) dtype=float32>, 'PReLU1': <tf.Tensor 'PReLU1/add:0' shape=(None, None, None, 10) dtype=float32>, 'pool1': <tf.Tensor 'pool1:0' shape=(None, None, None, 10) dtype=float32>, 'conv2': <tf.Tensor 'conv2/BiasAdd:0' shape=(None, None, None, 16) dtype=float32>, 'PReLU2': <tf.Tensor 'PReLU2/add:0' shape=(None, None, None, 16) dtype=float32>, 'conv3': <tf.Tensor 'conv3/BiasAdd:0' shape=(None, None, None, 32) dtype=float32>, 'PReLU3': <tf.Tensor 'PReLU3/add:0' shape=(None, None, None, 32) dtype=float32>, 'conv4-1': <tf.Tensor 'conv4-1/BiasAdd:0' shape=(None, None, None, 2) dtype=float32>, 'prob1': <tf.Tensor 'prob1:0' shape=(None, None, None, 2) dtype=float32>, 'conv4-2': <tf.Tensor 'conv4-2/BiasAdd:0' shape=(None, None, None, 4) dtype=float32>} --after
# ----layer_decorated----
# Tensor("rnet/input:0", shape=(None, 24, 24, 3), dtype=float32) --input conv
# Tensor("rnet/conv1/BiasAdd:0", shape=(None, 22, 22, 28), dtype=float32) ---out conv
# {'data': <tf.Tensor 'rnet/input:0' shape=(None, 24, 24, 3) dtype=float32>, 'conv1': <tf.Tensor 'rnet/conv1/BiasAdd:0' shape=(None, 22, 22, 28) dtype=float32>} --after
# ----layer_decorated----
# Tensor("rnet/conv1/BiasAdd:0", shape=(None, 22, 22, 28), dtype=float32) ---input prelu
# Tensor("rnet/prelu1/add:0", shape=(None, 22, 22, 28), dtype=float32) ---out prelu
# {'data': <tf.Tensor 'rnet/input:0' shape=(None, 24, 24, 3) dtype=float32>, 'conv1': <tf.Tensor 'rnet/conv1/BiasAdd:0' shape=(None, 22, 22, 28) dtype=float32>, 'prelu1': <tf.Tensor 'rnet/prelu1/add:0' shape=(None, 22, 22, 28) dtype=float32>} --after
# ----layer_decorated----
# Tensor("rnet/prelu1/add:0", shape=(None, 22, 22, 28), dtype=float32) ---input maxpool
# Tensor("rnet/pool1:0", shape=(None, 11, 11, 28), dtype=float32) ---out maxpool
# {'data': <tf.Tensor 'rnet/input:0' shape=(None, 24, 24, 3) dtype=float32>, 'conv1': <tf.Tensor 'rnet/conv1/BiasAdd:0' shape=(None, 22, 22, 28) dtype=float32>, 'prelu1': <tf.Tensor 'rnet/prelu1/add:0' shape=(None, 22, 22, 28) dtype=float32>, 'pool1': <tf.Tensor 'rnet/pool1:0' shape=(None, 11, 11, 28) dtype=float32>} --after
# ----layer_decorated----
# Tensor("rnet/pool1:0", shape=(None, 11, 11, 28), dtype=float32) --input conv
# Tensor("rnet/conv2/BiasAdd:0", shape=(None, 9, 9, 48), dtype=float32) ---out conv
# {'data': <tf.Tensor 'rnet/input:0' shape=(None, 24, 24, 3) dtype=float32>, 'conv1': <tf.Tensor 'rnet/conv1/BiasAdd:0' shape=(None, 22, 22, 28) dtype=float32>, 'prelu1': <tf.Tensor 'rnet/prelu1/add:0' shape=(None, 22, 22, 28) dtype=float32>, 'pool1': <tf.Tensor 'rnet/pool1:0' shape=(None, 11, 11, 28) dtype=float32>, 'conv2': <tf.Tensor 'rnet/conv2/BiasAdd:0' shape=(None, 9, 9, 48) dtype=float32>} --after
# ----layer_decorated----
# Tensor("rnet/conv2/BiasAdd:0", shape=(None, 9, 9, 48), dtype=float32) ---input prelu
# Tensor("rnet/prelu2/add:0", shape=(None, 9, 9, 48), dtype=float32) ---out prelu
# {'data': <tf.Tensor 'rnet/input:0' shape=(None, 24, 24, 3) dtype=float32>, 'conv1': <tf.Tensor 'rnet/conv1/BiasAdd:0' shape=(None, 22, 22, 28) dtype=float32>, 'prelu1': <tf.Tensor 'rnet/prelu1/add:0' shape=(None, 22, 22, 28) dtype=float32>, 'pool1': <tf.Tensor 'rnet/pool1:0' shape=(None, 11, 11, 28) dtype=float32>, 'conv2': <tf.Tensor 'rnet/conv2/BiasAdd:0' shape=(None, 9, 9, 48) dtype=float32>, 'prelu2': <tf.Tensor 'rnet/prelu2/add:0' shape=(None, 9, 9, 48) dtype=float32>} --after
# ----layer_decorated----
# Tensor("rnet/prelu2/add:0", shape=(None, 9, 9, 48), dtype=float32) ---input maxpool
# Tensor("rnet/pool2:0", shape=(None, 4, 4, 48), dtype=float32) ---out maxpool
# {'data': <tf.Tensor 'rnet/input:0' shape=(None, 24, 24, 3) dtype=float32>, 'conv1': <tf.Tensor 'rnet/conv1/BiasAdd:0' shape=(None, 22, 22, 28) dtype=float32>, 'prelu1': <tf.Tensor 'rnet/prelu1/add:0' shape=(None, 22, 22, 28) dtype=float32>, 'pool1': <tf.Tensor 'rnet/pool1:0' shape=(None, 11, 11, 28) dtype=float32>, 'conv2': <tf.Tensor 'rnet/conv2/BiasAdd:0' shape=(None, 9, 9, 48) dtype=float32>, 'prelu2': <tf.Tensor 'rnet/prelu2/add:0' shape=(None, 9, 9, 48) dtype=float32>, 'pool2': <tf.Tensor 'rnet/pool2:0' shape=(None, 4, 4, 48) dtype=float32>} --after
# ----layer_decorated----
# Tensor("rnet/pool2:0", shape=(None, 4, 4, 48), dtype=float32) --input conv
# Tensor("rnet/conv3/BiasAdd:0", shape=(None, 3, 3, 64), dtype=float32) ---out conv
# {'data': <tf.Tensor 'rnet/input:0' shape=(None, 24, 24, 3) dtype=float32>, 'conv1': <tf.Tensor 'rnet/conv1/BiasAdd:0' shape=(None, 22, 22, 28) dtype=float32>, 'prelu1': <tf.Tensor 'rnet/prelu1/add:0' shape=(None, 22, 22, 28) dtype=float32>, 'pool1': <tf.Tensor 'rnet/pool1:0' shape=(None, 11, 11, 28) dtype=float32>, 'conv2': <tf.Tensor 'rnet/conv2/BiasAdd:0' shape=(None, 9, 9, 48) dtype=float32>, 'prelu2': <tf.Tensor 'rnet/prelu2/add:0' shape=(None, 9, 9, 48) dtype=float32>, 'pool2': <tf.Tensor 'rnet/pool2:0' shape=(None, 4, 4, 48) dtype=float32>, 'conv3': <tf.Tensor 'rnet/conv3/BiasAdd:0' shape=(None, 3, 3, 64) dtype=float32>} --after
# ----layer_decorated----
# Tensor("rnet/conv3/BiasAdd:0", shape=(None, 3, 3, 64), dtype=float32) ---input prelu
# Tensor("rnet/prelu3/add:0", shape=(None, 3, 3, 64), dtype=float32) ---out prelu
# {'data': <tf.Tensor 'rnet/input:0' shape=(None, 24, 24, 3) dtype=float32>, 'conv1': <tf.Tensor 'rnet/conv1/BiasAdd:0' shape=(None, 22, 22, 28) dtype=float32>, 'prelu1': <tf.Tensor 'rnet/prelu1/add:0' shape=(None, 22, 22, 28) dtype=float32>, 'pool1': <tf.Tensor 'rnet/pool1:0' shape=(None, 11, 11, 28) dtype=float32>, 'conv2': <tf.Tensor 'rnet/conv2/BiasAdd:0' shape=(None, 9, 9, 48) dtype=float32>, 'prelu2': <tf.Tensor 'rnet/prelu2/add:0' shape=(None, 9, 9, 48) dtype=float32>, 'pool2': <tf.Tensor 'rnet/pool2:0' shape=(None, 4, 4, 48) dtype=float32>, 'conv3': <tf.Tensor 'rnet/conv3/BiasAdd:0' shape=(None, 3, 3, 64) dtype=float32>, 'prelu3': <tf.Tensor 'rnet/prelu3/add:0' shape=(None, 3, 3, 64) dtype=float32>} --after
# ----layer_decorated----
# {'data': <tf.Tensor 'rnet/input:0' shape=(None, 24, 24, 3) dtype=float32>, 'conv1': <tf.Tensor 'rnet/conv1/BiasAdd:0' shape=(None, 22, 22, 28) dtype=float32>, 'prelu1': <tf.Tensor 'rnet/prelu1/add:0' shape=(None, 22, 22, 28) dtype=float32>, 'pool1': <tf.Tensor 'rnet/pool1:0' shape=(None, 11, 11, 28) dtype=float32>, 'conv2': <tf.Tensor 'rnet/conv2/BiasAdd:0' shape=(None, 9, 9, 48) dtype=float32>, 'prelu2': <tf.Tensor 'rnet/prelu2/add:0' shape=(None, 9, 9, 48) dtype=float32>, 'pool2': <tf.Tensor 'rnet/pool2:0' shape=(None, 4, 4, 48) dtype=float32>, 'conv3': <tf.Tensor 'rnet/conv3/BiasAdd:0' shape=(None, 3, 3, 64) dtype=float32>, 'prelu3': <tf.Tensor 'rnet/prelu3/add:0' shape=(None, 3, 3, 64) dtype=float32>, 'conv4': <tf.Tensor 'rnet/conv4/conv4:0' shape=(None, 128) dtype=float32>} --after
# ----layer_decorated----
# Tensor("rnet/conv4/conv4:0", shape=(None, 128), dtype=float32) ---input prelu
# Tensor("rnet/prelu4/add:0", shape=(None, 128), dtype=float32) ---out prelu
# {'data': <tf.Tensor 'rnet/input:0' shape=(None, 24, 24, 3) dtype=float32>, 'conv1': <tf.Tensor 'rnet/conv1/BiasAdd:0' shape=(None, 22, 22, 28) dtype=float32>, 'prelu1': <tf.Tensor 'rnet/prelu1/add:0' shape=(None, 22, 22, 28) dtype=float32>, 'pool1': <tf.Tensor 'rnet/pool1:0' shape=(None, 11, 11, 28) dtype=float32>, 'conv2': <tf.Tensor 'rnet/conv2/BiasAdd:0' shape=(None, 9, 9, 48) dtype=float32>, 'prelu2': <tf.Tensor 'rnet/prelu2/add:0' shape=(None, 9, 9, 48) dtype=float32>, 'pool2': <tf.Tensor 'rnet/pool2:0' shape=(None, 4, 4, 48) dtype=float32>, 'conv3': <tf.Tensor 'rnet/conv3/BiasAdd:0' shape=(None, 3, 3, 64) dtype=float32>, 'prelu3': <tf.Tensor 'rnet/prelu3/add:0' shape=(None, 3, 3, 64) dtype=float32>, 'conv4': <tf.Tensor 'rnet/conv4/conv4:0' shape=(None, 128) dtype=float32>, 'prelu4': <tf.Tensor 'rnet/prelu4/add:0' shape=(None, 128) dtype=float32>} --after
# ----layer_decorated----
# {'data': <tf.Tensor 'rnet/input:0' shape=(None, 24, 24, 3) dtype=float32>, 'conv1': <tf.Tensor 'rnet/conv1/BiasAdd:0' shape=(None, 22, 22, 28) dtype=float32>, 'prelu1': <tf.Tensor 'rnet/prelu1/add:0' shape=(None, 22, 22, 28) dtype=float32>, 'pool1': <tf.Tensor 'rnet/pool1:0' shape=(None, 11, 11, 28) dtype=float32>, 'conv2': <tf.Tensor 'rnet/conv2/BiasAdd:0' shape=(None, 9, 9, 48) dtype=float32>, 'prelu2': <tf.Tensor 'rnet/prelu2/add:0' shape=(None, 9, 9, 48) dtype=float32>, 'pool2': <tf.Tensor 'rnet/pool2:0' shape=(None, 4, 4, 48) dtype=float32>, 'conv3': <tf.Tensor 'rnet/conv3/BiasAdd:0' shape=(None, 3, 3, 64) dtype=float32>, 'prelu3': <tf.Tensor 'rnet/prelu3/add:0' shape=(None, 3, 3, 64) dtype=float32>, 'conv4': <tf.Tensor 'rnet/conv4/conv4:0' shape=(None, 128) dtype=float32>, 'prelu4': <tf.Tensor 'rnet/prelu4/add:0' shape=(None, 128) dtype=float32>, 'conv5-1': <tf.Tensor 'rnet/conv5-1/conv5-1:0' shape=(None, 2) dtype=float32>} --after
# ----layer_decorated----
# Tensor("rnet/conv5-1/conv5-1:0", shape=(None, 2), dtype=float32) ---target softmax
# Tensor("rnet/prob1:0", shape=(None, 2), dtype=float32) ---out softmax
# {'data': <tf.Tensor 'rnet/input:0' shape=(None, 24, 24, 3) dtype=float32>, 'conv1': <tf.Tensor 'rnet/conv1/BiasAdd:0' shape=(None, 22, 22, 28) dtype=float32>, 'prelu1': <tf.Tensor 'rnet/prelu1/add:0' shape=(None, 22, 22, 28) dtype=float32>, 'pool1': <tf.Tensor 'rnet/pool1:0' shape=(None, 11, 11, 28) dtype=float32>, 'conv2': <tf.Tensor 'rnet/conv2/BiasAdd:0' shape=(None, 9, 9, 48) dtype=float32>, 'prelu2': <tf.Tensor 'rnet/prelu2/add:0' shape=(None, 9, 9, 48) dtype=float32>, 'pool2': <tf.Tensor 'rnet/pool2:0' shape=(None, 4, 4, 48) dtype=float32>, 'conv3': <tf.Tensor 'rnet/conv3/BiasAdd:0' shape=(None, 3, 3, 64) dtype=float32>, 'prelu3': <tf.Tensor 'rnet/prelu3/add:0' shape=(None, 3, 3, 64) dtype=float32>, 'conv4': <tf.Tensor 'rnet/conv4/conv4:0' shape=(None, 128) dtype=float32>, 'prelu4': <tf.Tensor 'rnet/prelu4/add:0' shape=(None, 128) dtype=float32>, 'conv5-1': <tf.Tensor 'rnet/conv5-1/conv5-1:0' shape=(None, 2) dtype=float32>, 'prob1': <tf.Tensor 'rnet/prob1:0' shape=(None, 2) dtype=float32>} --after
# ----layer_decorated----
# {'data': <tf.Tensor 'rnet/input:0' shape=(None, 24, 24, 3) dtype=float32>, 'conv1': <tf.Tensor 'rnet/conv1/BiasAdd:0' shape=(None, 22, 22, 28) dtype=float32>, 'prelu1': <tf.Tensor 'rnet/prelu1/add:0' shape=(None, 22, 22, 28) dtype=float32>, 'pool1': <tf.Tensor 'rnet/pool1:0' shape=(None, 11, 11, 28) dtype=float32>, 'conv2': <tf.Tensor 'rnet/conv2/BiasAdd:0' shape=(None, 9, 9, 48) dtype=float32>, 'prelu2': <tf.Tensor 'rnet/prelu2/add:0' shape=(None, 9, 9, 48) dtype=float32>, 'pool2': <tf.Tensor 'rnet/pool2:0' shape=(None, 4, 4, 48) dtype=float32>, 'conv3': <tf.Tensor 'rnet/conv3/BiasAdd:0' shape=(None, 3, 3, 64) dtype=float32>, 'prelu3': <tf.Tensor 'rnet/prelu3/add:0' shape=(None, 3, 3, 64) dtype=float32>, 'conv4': <tf.Tensor 'rnet/conv4/conv4:0' shape=(None, 128) dtype=float32>, 'prelu4': <tf.Tensor 'rnet/prelu4/add:0' shape=(None, 128) dtype=float32>, 'conv5-1': <tf.Tensor 'rnet/conv5-1/conv5-1:0' shape=(None, 2) dtype=float32>, 'prob1': <tf.Tensor 'rnet/prob1:0' shape=(None, 2) dtype=float32>, 'conv5-2': <tf.Tensor 'rnet/conv5-2/conv5-2:0' shape=(None, 4) dtype=float32>} --after
# ----layer_decorated----
# Tensor("onet/input:0", shape=(None, 48, 48, 3), dtype=float32) --input conv
# Tensor("onet/conv1/BiasAdd:0", shape=(None, 46, 46, 32), dtype=float32) ---out conv
# {'data': <tf.Tensor 'onet/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>} --after
# ----layer_decorated----
# Tensor("onet/conv1/BiasAdd:0", shape=(None, 46, 46, 32), dtype=float32) ---input prelu
# Tensor("onet/prelu1/add:0", shape=(None, 46, 46, 32), dtype=float32) ---out prelu
# {'data': <tf.Tensor 'onet/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>} --after
# ----layer_decorated----
# Tensor("onet/prelu1/add:0", shape=(None, 46, 46, 32), dtype=float32) ---input maxpool
# Tensor("onet/pool1:0", shape=(None, 23, 23, 32), dtype=float32) ---out maxpool
# {'data': <tf.Tensor 'onet/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet/pool1:0' shape=(None, 23, 23, 32) dtype=float32>} --after
# ----layer_decorated----
# Tensor("onet/pool1:0", shape=(None, 23, 23, 32), dtype=float32) --input conv
# Tensor("onet/conv2/BiasAdd:0", shape=(None, 21, 21, 64), dtype=float32) ---out conv
# {'data': <tf.Tensor 'onet/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>} --after
# ----layer_decorated----
# Tensor("onet/conv2/BiasAdd:0", shape=(None, 21, 21, 64), dtype=float32) ---input prelu
# Tensor("onet/prelu2/add:0", shape=(None, 21, 21, 64), dtype=float32) ---out prelu
# {'data': <tf.Tensor 'onet/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>, 'prelu2': <tf.Tensor 'onet/prelu2/add:0' shape=(None, 21, 21, 64) dtype=float32>} --after
# ----layer_decorated----
# Tensor("onet/prelu2/add:0", shape=(None, 21, 21, 64), dtype=float32) ---input maxpool
# Tensor("onet/pool2:0", shape=(None, 10, 10, 64), dtype=float32) ---out maxpool
# {'data': <tf.Tensor 'onet/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>, 'prelu2': <tf.Tensor 'onet/prelu2/add:0' shape=(None, 21, 21, 64) dtype=float32>, 'pool2': <tf.Tensor 'onet/pool2:0' shape=(None, 10, 10, 64) dtype=float32>} --after
# ----layer_decorated----
# Tensor("onet/pool2:0", shape=(None, 10, 10, 64), dtype=float32) --input conv
# Tensor("onet/conv3/BiasAdd:0", shape=(None, 8, 8, 64), dtype=float32) ---out conv
# {'data': <tf.Tensor 'onet/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>, 'prelu2': <tf.Tensor 'onet/prelu2/add:0' shape=(None, 21, 21, 64) dtype=float32>, 'pool2': <tf.Tensor 'onet/pool2:0' shape=(None, 10, 10, 64) dtype=float32>, 'conv3': <tf.Tensor 'onet/conv3/BiasAdd:0' shape=(None, 8, 8, 64) dtype=float32>} --after
# ----layer_decorated----
# Tensor("onet/conv3/BiasAdd:0", shape=(None, 8, 8, 64), dtype=float32) ---input prelu
# Tensor("onet/prelu3/add:0", shape=(None, 8, 8, 64), dtype=float32) ---out prelu
# {'data': <tf.Tensor 'onet/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>, 'prelu2': <tf.Tensor 'onet/prelu2/add:0' shape=(None, 21, 21, 64) dtype=float32>, 'pool2': <tf.Tensor 'onet/pool2:0' shape=(None, 10, 10, 64) dtype=float32>, 'conv3': <tf.Tensor 'onet/conv3/BiasAdd:0' shape=(None, 8, 8, 64) dtype=float32>, 'prelu3': <tf.Tensor 'onet/prelu3/add:0' shape=(None, 8, 8, 64) dtype=float32>} --after
# ----layer_decorated----
# Tensor("onet/prelu3/add:0", shape=(None, 8, 8, 64), dtype=float32) ---input maxpool
# Tensor("onet/pool3:0", shape=(None, 4, 4, 64), dtype=float32) ---out maxpool
# {'data': <tf.Tensor 'onet/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>, 'prelu2': <tf.Tensor 'onet/prelu2/add:0' shape=(None, 21, 21, 64) dtype=float32>, 'pool2': <tf.Tensor 'onet/pool2:0' shape=(None, 10, 10, 64) dtype=float32>, 'conv3': <tf.Tensor 'onet/conv3/BiasAdd:0' shape=(None, 8, 8, 64) dtype=float32>, 'prelu3': <tf.Tensor 'onet/prelu3/add:0' shape=(None, 8, 8, 64) dtype=float32>, 'pool3': <tf.Tensor 'onet/pool3:0' shape=(None, 4, 4, 64) dtype=float32>} --after
# ----layer_decorated----
# Tensor("onet/pool3:0", shape=(None, 4, 4, 64), dtype=float32) --input conv
# Tensor("onet/conv4/BiasAdd:0", shape=(None, 3, 3, 128), dtype=float32) ---out conv
# {'data': <tf.Tensor 'onet/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>, 'prelu2': <tf.Tensor 'onet/prelu2/add:0' shape=(None, 21, 21, 64) dtype=float32>, 'pool2': <tf.Tensor 'onet/pool2:0' shape=(None, 10, 10, 64) dtype=float32>, 'conv3': <tf.Tensor 'onet/conv3/BiasAdd:0' shape=(None, 8, 8, 64) dtype=float32>, 'prelu3': <tf.Tensor 'onet/prelu3/add:0' shape=(None, 8, 8, 64) dtype=float32>, 'pool3': <tf.Tensor 'onet/pool3:0' shape=(None, 4, 4, 64) dtype=float32>, 'conv4': <tf.Tensor 'onet/conv4/BiasAdd:0' shape=(None, 3, 3, 128) dtype=float32>} --after
# ----layer_decorated----
# Tensor("onet/conv4/BiasAdd:0", shape=(None, 3, 3, 128), dtype=float32) ---input prelu
# Tensor("onet/prelu4/add:0", shape=(None, 3, 3, 128), dtype=float32) ---out prelu
# {'data': <tf.Tensor 'onet/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>, 'prelu2': <tf.Tensor 'onet/prelu2/add:0' shape=(None, 21, 21, 64) dtype=float32>, 'pool2': <tf.Tensor 'onet/pool2:0' shape=(None, 10, 10, 64) dtype=float32>, 'conv3': <tf.Tensor 'onet/conv3/BiasAdd:0' shape=(None, 8, 8, 64) dtype=float32>, 'prelu3': <tf.Tensor 'onet/prelu3/add:0' shape=(None, 8, 8, 64) dtype=float32>, 'pool3': <tf.Tensor 'onet/pool3:0' shape=(None, 4, 4, 64) dtype=float32>, 'conv4': <tf.Tensor 'onet/conv4/BiasAdd:0' shape=(None, 3, 3, 128) dtype=float32>, 'prelu4': <tf.Tensor 'onet/prelu4/add:0' shape=(None, 3, 3, 128) dtype=float32>} --after
# ----layer_decorated----
# {'data': <tf.Tensor 'onet/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>, 'prelu2': <tf.Tensor 'onet/prelu2/add:0' shape=(None, 21, 21, 64) dtype=float32>, 'pool2': <tf.Tensor 'onet/pool2:0' shape=(None, 10, 10, 64) dtype=float32>, 'conv3': <tf.Tensor 'onet/conv3/BiasAdd:0' shape=(None, 8, 8, 64) dtype=float32>, 'prelu3': <tf.Tensor 'onet/prelu3/add:0' shape=(None, 8, 8, 64) dtype=float32>, 'pool3': <tf.Tensor 'onet/pool3:0' shape=(None, 4, 4, 64) dtype=float32>, 'conv4': <tf.Tensor 'onet/conv4/BiasAdd:0' shape=(None, 3, 3, 128) dtype=float32>, 'prelu4': <tf.Tensor 'onet/prelu4/add:0' shape=(None, 3, 3, 128) dtype=float32>, 'conv5': <tf.Tensor 'onet/conv5/conv5:0' shape=(None, 256) dtype=float32>} --after
# ----layer_decorated----
# Tensor("onet/conv5/conv5:0", shape=(None, 256), dtype=float32) ---input prelu
# Tensor("onet/prelu5/add:0", shape=(None, 256), dtype=float32) ---out prelu
# {'data': <tf.Tensor 'onet/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>, 'prelu2': <tf.Tensor 'onet/prelu2/add:0' shape=(None, 21, 21, 64) dtype=float32>, 'pool2': <tf.Tensor 'onet/pool2:0' shape=(None, 10, 10, 64) dtype=float32>, 'conv3': <tf.Tensor 'onet/conv3/BiasAdd:0' shape=(None, 8, 8, 64) dtype=float32>, 'prelu3': <tf.Tensor 'onet/prelu3/add:0' shape=(None, 8, 8, 64) dtype=float32>, 'pool3': <tf.Tensor 'onet/pool3:0' shape=(None, 4, 4, 64) dtype=float32>, 'conv4': <tf.Tensor 'onet/conv4/BiasAdd:0' shape=(None, 3, 3, 128) dtype=float32>, 'prelu4': <tf.Tensor 'onet/prelu4/add:0' shape=(None, 3, 3, 128) dtype=float32>, 'conv5': <tf.Tensor 'onet/conv5/conv5:0' shape=(None, 256) dtype=float32>, 'prelu5': <tf.Tensor 'onet/prelu5/add:0' shape=(None, 256) dtype=float32>} --after
# ----layer_decorated----
# {'data': <tf.Tensor 'onet/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>, 'prelu2': <tf.Tensor 'onet/prelu2/add:0' shape=(None, 21, 21, 64) dtype=float32>, 'pool2': <tf.Tensor 'onet/pool2:0' shape=(None, 10, 10, 64) dtype=float32>, 'conv3': <tf.Tensor 'onet/conv3/BiasAdd:0' shape=(None, 8, 8, 64) dtype=float32>, 'prelu3': <tf.Tensor 'onet/prelu3/add:0' shape=(None, 8, 8, 64) dtype=float32>, 'pool3': <tf.Tensor 'onet/pool3:0' shape=(None, 4, 4, 64) dtype=float32>, 'conv4': <tf.Tensor 'onet/conv4/BiasAdd:0' shape=(None, 3, 3, 128) dtype=float32>, 'prelu4': <tf.Tensor 'onet/prelu4/add:0' shape=(None, 3, 3, 128) dtype=float32>, 'conv5': <tf.Tensor 'onet/conv5/conv5:0' shape=(None, 256) dtype=float32>, 'prelu5': <tf.Tensor 'onet/prelu5/add:0' shape=(None, 256) dtype=float32>, 'conv6-1': <tf.Tensor 'onet/conv6-1/conv6-1:0' shape=(None, 2) dtype=float32>} --after
# ----layer_decorated----
# Tensor("onet/conv6-1/conv6-1:0", shape=(None, 2), dtype=float32) ---target softmax
# Tensor("onet/prob1:0", shape=(None, 2), dtype=float32) ---out softmax
# {'data': <tf.Tensor 'onet/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>, 'prelu2': <tf.Tensor 'onet/prelu2/add:0' shape=(None, 21, 21, 64) dtype=float32>, 'pool2': <tf.Tensor 'onet/pool2:0' shape=(None, 10, 10, 64) dtype=float32>, 'conv3': <tf.Tensor 'onet/conv3/BiasAdd:0' shape=(None, 8, 8, 64) dtype=float32>, 'prelu3': <tf.Tensor 'onet/prelu3/add:0' shape=(None, 8, 8, 64) dtype=float32>, 'pool3': <tf.Tensor 'onet/pool3:0' shape=(None, 4, 4, 64) dtype=float32>, 'conv4': <tf.Tensor 'onet/conv4/BiasAdd:0' shape=(None, 3, 3, 128) dtype=float32>, 'prelu4': <tf.Tensor 'onet/prelu4/add:0' shape=(None, 3, 3, 128) dtype=float32>, 'conv5': <tf.Tensor 'onet/conv5/conv5:0' shape=(None, 256) dtype=float32>, 'prelu5': <tf.Tensor 'onet/prelu5/add:0' shape=(None, 256) dtype=float32>, 'conv6-1': <tf.Tensor 'onet/conv6-1/conv6-1:0' shape=(None, 2) dtype=float32>, 'prob1': <tf.Tensor 'onet/prob1:0' shape=(None, 2) dtype=float32>} --after
# ----layer_decorated----
# {'data': <tf.Tensor 'onet/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>, 'prelu2': <tf.Tensor 'onet/prelu2/add:0' shape=(None, 21, 21, 64) dtype=float32>, 'pool2': <tf.Tensor 'onet/pool2:0' shape=(None, 10, 10, 64) dtype=float32>, 'conv3': <tf.Tensor 'onet/conv3/BiasAdd:0' shape=(None, 8, 8, 64) dtype=float32>, 'prelu3': <tf.Tensor 'onet/prelu3/add:0' shape=(None, 8, 8, 64) dtype=float32>, 'pool3': <tf.Tensor 'onet/pool3:0' shape=(None, 4, 4, 64) dtype=float32>, 'conv4': <tf.Tensor 'onet/conv4/BiasAdd:0' shape=(None, 3, 3, 128) dtype=float32>, 'prelu4': <tf.Tensor 'onet/prelu4/add:0' shape=(None, 3, 3, 128) dtype=float32>, 'conv5': <tf.Tensor 'onet/conv5/conv5:0' shape=(None, 256) dtype=float32>, 'prelu5': <tf.Tensor 'onet/prelu5/add:0' shape=(None, 256) dtype=float32>, 'conv6-1': <tf.Tensor 'onet/conv6-1/conv6-1:0' shape=(None, 2) dtype=float32>, 'prob1': <tf.Tensor 'onet/prob1:0' shape=(None, 2) dtype=float32>, 'conv6-2': <tf.Tensor 'onet/conv6-2/conv6-2:0' shape=(None, 4) dtype=float32>} --after
# ----layer_decorated----
# {'data': <tf.Tensor 'onet/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>, 'prelu2': <tf.Tensor 'onet/prelu2/add:0' shape=(None, 21, 21, 64) dtype=float32>, 'pool2': <tf.Tensor 'onet/pool2:0' shape=(None, 10, 10, 64) dtype=float32>, 'conv3': <tf.Tensor 'onet/conv3/BiasAdd:0' shape=(None, 8, 8, 64) dtype=float32>, 'prelu3': <tf.Tensor 'onet/prelu3/add:0' shape=(None, 8, 8, 64) dtype=float32>, 'pool3': <tf.Tensor 'onet/pool3:0' shape=(None, 4, 4, 64) dtype=float32>, 'conv4': <tf.Tensor 'onet/conv4/BiasAdd:0' shape=(None, 3, 3, 128) dtype=float32>, 'prelu4': <tf.Tensor 'onet/prelu4/add:0' shape=(None, 3, 3, 128) dtype=float32>, 'conv5': <tf.Tensor 'onet/conv5/conv5:0' shape=(None, 256) dtype=float32>, 'prelu5': <tf.Tensor 'onet/prelu5/add:0' shape=(None, 256) dtype=float32>, 'conv6-1': <tf.Tensor 'onet/conv6-1/conv6-1:0' shape=(None, 2) dtype=float32>, 'prob1': <tf.Tensor 'onet/prob1:0' shape=(None, 2) dtype=float32>, 'conv6-2': <tf.Tensor 'onet/conv6-2/conv6-2:0' shape=(None, 4) dtype=float32>, 'conv6-3': <tf.Tensor 'onet/conv6-3/conv6-3:0' shape=(None, 10) dtype=float32>} --after
# ----layer_decorated----

# %%
ls
# Out:
#  cat.cms               'MicrosoftTeams-image (1).jpg'
#  CroppingModels.ipynb   models/
#  detector/              mtcnn_detect_face.py
#  elg_weights/           mtcnn_weights/
#  EyesCropping2.ipynb    no_face.jpg
#  EyesCropping.ipynb     __pycache__/
#  faace.jpg              sunglasses_no_sunglasses.jpg
#  fuzzyfaces.jpg         sunnglasses.jpg
#  image.jpeg

# %%
img_path = "image.jpeg"
input_img = cv2.imread(img_path)[..., ::-1]
plt.imshow(input_img)

# %%
# face, lms = fd.detect_face(input_img) # assuming there is only one face in input image
# assert len(face) >= 1, "No face detected"

# %%
# left_eye_im, right_eye_im = fd.cropImage(input_img,lms)

# %%
# left_eye_xy = np.array([lms[6], lms[1]])
# right_eye_xy = np.array([lms[5], lms[0]])
# nouse = np.array([lms[7], lms[2]])
# right_mouth=np.array([lms[8], lms[3]])
# left_mouth=np.array([lms[9], lms[4]])

# dist_eyes = np.linalg.norm(left_eye_xy - right_eye_xy)
# eye_bbox_w = (dist_eyes / 1.25)
# eye_bbox_h = (eye_bbox_w *0.6)

# plt.figure(figsize=(15,4))
# draw = input_img.copy()
# for i, lm in enumerate([left_eye_xy, right_eye_xy]):
#     draw = cv2.circle(draw, (int(lm[1]), int(lm[0])), 15, (255*i,255*(1-i),0), -1)
# draw = cv2.circle(draw, (int(nouse[1]), int(nouse[0])), 15, (255,255*(1-0),0), -1)
# for i, lm in enumerate([left_mouth, right_mouth]):
#     draw = cv2.circle(draw, (int(lm[1]), int(lm[0])), 15, (255*i,255*(1-i),0), -1)

# plt.subplot(1,3,1)
# plt.title('Annotation')
# plt.imshow(draw)
# plt.subplot(1,3,2)
# plt.title('Left eye')
# plt.imshow(left_eye_im)
# plt.subplot(1,3,3)
# plt.title('Right eye')
# plt.imshow(right_eye_im)

# %%
# from models.elg_keras import KerasELG
# model = KerasELG()
# model.net.load_weights("./elg_weights/elg_keras.h5")

# %%
# inp_left = cv2.cvtColor(left_eye_im, cv2.COLOR_RGB2GRAY)
# inp_left = cv2.equalizeHist(inp_left)
# inp_left = cv2.resize(inp_left, (180,108))[np.newaxis, ..., np.newaxis]

# inp_right = cv2.cvtColor(right_eye_im, cv2.COLOR_RGB2GRAY)
# inp_right = cv2.equalizeHist(inp_right)
# inp_right = cv2.resize(inp_right, (180,108))[np.newaxis, ..., np.newaxis]

# %%
# input_array = np.concatenate([inp_left, inp_right], axis=0)
# pred_left, pred_right = model.net.predict(input_array/255 * 2 - 1)

# %%
# def draw_pupil(im, inp_im, lms):
#     draw = im.copy()
#     #print(draw.shape)
#     draw = cv2.resize(draw, (inp_im.shape[2], inp_im.shape[1]))
#     stroke = inp_im.shape[1] // 30
#     for i, lm in enumerate(np.squeeze(lms)):

#         x, y = int(lm[0]*3), int(lm[1]*3)
#         if i < 8:
#             draw = cv2.circle(draw, (x, y), stroke, (125,255,125), -1)
#         elif 8 <= i < 16:
#             draw = cv2.circle(draw, (x, y), stroke, (125,125,255), -1)         

#     return draw

# %%
# plt.figure(figsize=(15,4))
# plt.subplot(1,2,1)
# plt.title("Left eye")
# lms_left = model._calculate_landmarks(pred_left)
# result_left = draw_pupil(left_eye_im, inp_left, lms_left)
# plt.imshow(result_left)
# plt.subplot(1,2,2)
# plt.title("Right eye")
# lms_right = model._calculate_landmarks(pred_right)
# result_right = draw_pupil(right_eye_im, inp_right, lms_right)
# plt.imshow(result_right)

# %%
# plt.figure(figsize=(15,4))
# plt.subplot(1,2,1)
# plt.title("Left eye")
# cropped_left= right_eye_im[int(lms_left[0][10][1] * 3):int(lms_left[0][14][1] * 3),
#                 int(lms_left[0][0][0] * 3):int(lms_left[0][5][0] * 3)]
# plt.imshow(cropped_left)

# plt.subplot(1,2,2)
# plt.title("Right eye")
# cropped_right= right_eye_im[int(lms_right[0][10][1] * 3):int(lms_right[0][14][1] * 3),
#                 int(lms_right[0][0][0] * 3):int(lms_right[0][5][0] * 3)]
# plt.imshow(cropped_right)

# %%
from keras.models import load_model

# %% [markdown]
# ## Models Integration

# %%
def Image_croping(image , detect_model_path):
   ## loading wieghts
    fd = MTCNNFaceDetector(sess=tf.compat.v1.keras.backend.get_session(), model_path=detect_model_path)
    face, lms = fd.detect_face(image) 
    if len(face) == 1 :
        left_eye_im, right_eye_im = fd.cropImage(image,lms)
        return left_eye_im , right_eye_im , face
    if len(face) > 1 :
        return 'Multiple faces detected' , 'Multiple faces detected'  , face
    return 'no face detected' ,  'no face detected' , face


def Diagnosis(left_eye_im , right_eye_im , diagnosis_model_path):
    
    model = load_model(diagnosis_model_path)
    ###### left eye #### 
    left_eye_im = cv2.resize(left_eye_im, (100, 100))
    left_eye_im = left_eye_im.reshape(1 ,100 , 100 , -1)
    left_eye_im_diagnosis = model.predict(left_eye_im)
    if left_eye_im_diagnosis > 0.56:
        left_eye_im_desc =  ' Left Eye : Cataract detected'
    else :
        left_eye_im_desc = 'Left Eye : No Cataract detected'
    
    
    
    ##### right eye ### 
    right_eye_im = cv2.resize(right_eye_im, (100, 100))
    right_eye_im = right_eye_im.reshape(1 ,100 , 100 , -1)
    right_eye_im_diagnosis  = model.predict(right_eye_im)
    
    if right_eye_im_diagnosis > 0.56:
        right_eye_im_desc =  'Right Eye : Cataract detected'
    else :
        right_eye_im_desc = 'Right Eye : No Cataract detected'
    
    return left_eye_im_desc ,left_eye_im_diagnosis[0], right_eye_im_desc , right_eye_im_diagnosis[0]

def Main(image , detect_model_path , diagnosis_model_path):
    left_eye_im , right_eye_im , face = Image_croping(image , detect_model_path)
    
    if len(face) != 1 :
        return left_eye_im , left_eye_im, left_eye_im , left_eye_im , left_eye_im , left_eye_im 
        
    left_eye_im_desc ,left_eye_im_diagnosis, right_eye_im_desc , right_eye_im_diagnosis = Diagnosis(left_eye_im , right_eye_im , diagnosis_model_path)
    
    return left_eye_im , left_eye_im_desc , left_eye_im_diagnosis , right_eye_im , right_eye_im_desc , right_eye_im_diagnosis

# %%
ls
# Out:
# '7 - dr. Meiliana Lay.jpeg'  'M. Alim.JPG'
#  cat.jpg                     'MicrosoftTeams-image (1).jpg'
#  CroppingModels.ipynb         models/
#  detector/                    mtcnn_detect_face.py
#  elg_weights/                 mtcnn_weights/
#  EyesCropping2.ipynb          no_face.jpg
#  EyesCropping.ipynb           __pycache__/
#  faace.jpg                    sunglasses_no_sunglasses.jpg
#  fuzzyfaces.jpg               sunnglasses.jpg
#  image.jpeg                   unhealthy.jpg

# %%
diagnosis_model_path = '/home/khaldoun/Desktop/TOV_DataAcquisition/saved_models/Final_models/accuracy-92size100x100_Threshold_0.56.h5'
detect_model_path = "./mtcnn_weights/" 
img_path = "M. Alim.JPG"
image = cv2.imread(img_path)[..., ::-1]
left_eye_im , left_eye_im_desc , left_eye_im_diagnosis , right_eye_im , right_eye_im_desc , right_eye_im_diagnosis = Main(image , detect_model_path , diagnosis_model_path)
# Out:
# Tensor("pnet_4/input:0", shape=(None, None, None, 3), dtype=float32) --input conv
# Tensor("pnet_4/conv1/BiasAdd:0", shape=(None, None, None, 10), dtype=float32) ---out conv
# {'data': <tf.Tensor 'pnet_4/input:0' shape=(None, None, None, 3) dtype=float32>, 'conv1': <tf.Tensor 'pnet_4/conv1/BiasAdd:0' shape=(None, None, None, 10) dtype=float32>} --after
# ----layer_decorated----
# Tensor("pnet_4/conv1/BiasAdd:0", shape=(None, None, None, 10), dtype=float32) ---input prelu
# Tensor("pnet_4/PReLU1/add:0", shape=(None, None, None, 10), dtype=float32) ---out prelu
# {'data': <tf.Tensor 'pnet_4/input:0' shape=(None, None, None, 3) dtype=float32>, 'conv1': <tf.Tensor 'pnet_4/conv1/BiasAdd:0' shape=(None, None, None, 10) dtype=float32>, 'PReLU1': <tf.Tensor 'pnet_4/PReLU1/add:0' shape=(None, None, None, 10) dtype=float32>} --after
# ----layer_decorated----
# Tensor("pnet_4/PReLU1/add:0", shape=(None, None, None, 10), dtype=float32) ---input maxpool
# Tensor("pnet_4/pool1:0", shape=(None, None, None, 10), dtype=float32) ---out maxpool
# {'data': <tf.Tensor 'pnet_4/input:0' shape=(None, None, None, 3) dtype=float32>, 'conv1': <tf.Tensor 'pnet_4/conv1/BiasAdd:0' shape=(None, None, None, 10) dtype=float32>, 'PReLU1': <tf.Tensor 'pnet_4/PReLU1/add:0' shape=(None, None, None, 10) dtype=float32>, 'pool1': <tf.Tensor 'pnet_4/pool1:0' shape=(None, None, None, 10) dtype=float32>} --after
# ----layer_decorated----
# Tensor("pnet_4/pool1:0", shape=(None, None, None, 10), dtype=float32) --input conv
# Tensor("pnet_4/conv2/BiasAdd:0", shape=(None, None, None, 16), dtype=float32) ---out conv
# {'data': <tf.Tensor 'pnet_4/input:0' shape=(None, None, None, 3) dtype=float32>, 'conv1': <tf.Tensor 'pnet_4/conv1/BiasAdd:0' shape=(None, None, None, 10) dtype=float32>, 'PReLU1': <tf.Tensor 'pnet_4/PReLU1/add:0' shape=(None, None, None, 10) dtype=float32>, 'pool1': <tf.Tensor 'pnet_4/pool1:0' shape=(None, None, None, 10) dtype=float32>, 'conv2': <tf.Tensor 'pnet_4/conv2/BiasAdd:0' shape=(None, None, None, 16) dtype=float32>} --after
# ----layer_decorated----
# Tensor("pnet_4/conv2/BiasAdd:0", shape=(None, None, None, 16), dtype=float32) ---input prelu
# Tensor("pnet_4/PReLU2/add:0", shape=(None, None, None, 16), dtype=float32) ---out prelu
# {'data': <tf.Tensor 'pnet_4/input:0' shape=(None, None, None, 3) dtype=float32>, 'conv1': <tf.Tensor 'pnet_4/conv1/BiasAdd:0' shape=(None, None, None, 10) dtype=float32>, 'PReLU1': <tf.Tensor 'pnet_4/PReLU1/add:0' shape=(None, None, None, 10) dtype=float32>, 'pool1': <tf.Tensor 'pnet_4/pool1:0' shape=(None, None, None, 10) dtype=float32>, 'conv2': <tf.Tensor 'pnet_4/conv2/BiasAdd:0' shape=(None, None, None, 16) dtype=float32>, 'PReLU2': <tf.Tensor 'pnet_4/PReLU2/add:0' shape=(None, None, None, 16) dtype=float32>} --after
# ----layer_decorated----
# Tensor("pnet_4/PReLU2/add:0", shape=(None, None, None, 16), dtype=float32) --input conv
# Tensor("pnet_4/conv3/BiasAdd:0", shape=(None, None, None, 32), dtype=float32) ---out conv
# {'data': <tf.Tensor 'pnet_4/input:0' shape=(None, None, None, 3) dtype=float32>, 'conv1': <tf.Tensor 'pnet_4/conv1/BiasAdd:0' shape=(None, None, None, 10) dtype=float32>, 'PReLU1': <tf.Tensor 'pnet_4/PReLU1/add:0' shape=(None, None, None, 10) dtype=float32>, 'pool1': <tf.Tensor 'pnet_4/pool1:0' shape=(None, None, None, 10) dtype=float32>, 'conv2': <tf.Tensor 'pnet_4/conv2/BiasAdd:0' shape=(None, None, None, 16) dtype=float32>, 'PReLU2': <tf.Tensor 'pnet_4/PReLU2/add:0' shape=(None, None, None, 16) dtype=float32>, 'conv3': <tf.Tensor 'pnet_4/conv3/BiasAdd:0' shape=(None, None, None, 32) dtype=float32>} --after
# ----layer_decorated----
# Tensor("pnet_4/conv3/BiasAdd:0", shape=(None, None, None, 32), dtype=float32) ---input prelu
# Tensor("pnet_4/PReLU3/add:0", shape=(None, None, None, 32), dtype=float32) ---out prelu
# {'data': <tf.Tensor 'pnet_4/input:0' shape=(None, None, None, 3) dtype=float32>, 'conv1': <tf.Tensor 'pnet_4/conv1/BiasAdd:0' shape=(None, None, None, 10) dtype=float32>, 'PReLU1': <tf.Tensor 'pnet_4/PReLU1/add:0' shape=(None, None, None, 10) dtype=float32>, 'pool1': <tf.Tensor 'pnet_4/pool1:0' shape=(None, None, None, 10) dtype=float32>, 'conv2': <tf.Tensor 'pnet_4/conv2/BiasAdd:0' shape=(None, None, None, 16) dtype=float32>, 'PReLU2': <tf.Tensor 'pnet_4/PReLU2/add:0' shape=(None, None, None, 16) dtype=float32>, 'conv3': <tf.Tensor 'pnet_4/conv3/BiasAdd:0' shape=(None, None, None, 32) dtype=float32>, 'PReLU3': <tf.Tensor 'pnet_4/PReLU3/add:0' shape=(None, None, None, 32) dtype=float32>} --after
# ----layer_decorated----
# Tensor("pnet_4/PReLU3/add:0", shape=(None, None, None, 32), dtype=float32) --input conv
# Tensor("pnet_4/conv4-1/BiasAdd:0", shape=(None, None, None, 2), dtype=float32) ---out conv
# {'data': <tf.Tensor 'pnet_4/input:0' shape=(None, None, None, 3) dtype=float32>, 'conv1': <tf.Tensor 'pnet_4/conv1/BiasAdd:0' shape=(None, None, None, 10) dtype=float32>, 'PReLU1': <tf.Tensor 'pnet_4/PReLU1/add:0' shape=(None, None, None, 10) dtype=float32>, 'pool1': <tf.Tensor 'pnet_4/pool1:0' shape=(None, None, None, 10) dtype=float32>, 'conv2': <tf.Tensor 'pnet_4/conv2/BiasAdd:0' shape=(None, None, None, 16) dtype=float32>, 'PReLU2': <tf.Tensor 'pnet_4/PReLU2/add:0' shape=(None, None, None, 16) dtype=float32>, 'conv3': <tf.Tensor 'pnet_4/conv3/BiasAdd:0' shape=(None, None, None, 32) dtype=float32>, 'PReLU3': <tf.Tensor 'pnet_4/PReLU3/add:0' shape=(None, None, None, 32) dtype=float32>, 'conv4-1': <tf.Tensor 'pnet_4/conv4-1/BiasAdd:0' shape=(None, None, None, 2) dtype=float32>} --after
# ----layer_decorated----
# Tensor("pnet_4/conv4-1/BiasAdd:0", shape=(None, None, None, 2), dtype=float32) ---target softmax
# Tensor("pnet_4/prob1:0", shape=(None, None, None, 2), dtype=float32) ---out softmax
# {'data': <tf.Tensor 'pnet_4/input:0' shape=(None, None, None, 3) dtype=float32>, 'conv1': <tf.Tensor 'pnet_4/conv1/BiasAdd:0' shape=(None, None, None, 10) dtype=float32>, 'PReLU1': <tf.Tensor 'pnet_4/PReLU1/add:0' shape=(None, None, None, 10) dtype=float32>, 'pool1': <tf.Tensor 'pnet_4/pool1:0' shape=(None, None, None, 10) dtype=float32>, 'conv2': <tf.Tensor 'pnet_4/conv2/BiasAdd:0' shape=(None, None, None, 16) dtype=float32>, 'PReLU2': <tf.Tensor 'pnet_4/PReLU2/add:0' shape=(None, None, None, 16) dtype=float32>, 'conv3': <tf.Tensor 'pnet_4/conv3/BiasAdd:0' shape=(None, None, None, 32) dtype=float32>, 'PReLU3': <tf.Tensor 'pnet_4/PReLU3/add:0' shape=(None, None, None, 32) dtype=float32>, 'conv4-1': <tf.Tensor 'pnet_4/conv4-1/BiasAdd:0' shape=(None, None, None, 2) dtype=float32>, 'prob1': <tf.Tensor 'pnet_4/prob1:0' shape=(None, None, None, 2) dtype=float32>} --after
# ----layer_decorated----
# Tensor("pnet_4/PReLU3/add:0", shape=(None, None, None, 32), dtype=float32) --input conv
# Tensor("pnet_4/conv4-2/BiasAdd:0", shape=(None, None, None, 4), dtype=float32) ---out conv
# {'data': <tf.Tensor 'pnet_4/input:0' shape=(None, None, None, 3) dtype=float32>, 'conv1': <tf.Tensor 'pnet_4/conv1/BiasAdd:0' shape=(None, None, None, 10) dtype=float32>, 'PReLU1': <tf.Tensor 'pnet_4/PReLU1/add:0' shape=(None, None, None, 10) dtype=float32>, 'pool1': <tf.Tensor 'pnet_4/pool1:0' shape=(None, None, None, 10) dtype=float32>, 'conv2': <tf.Tensor 'pnet_4/conv2/BiasAdd:0' shape=(None, None, None, 16) dtype=float32>, 'PReLU2': <tf.Tensor 'pnet_4/PReLU2/add:0' shape=(None, None, None, 16) dtype=float32>, 'conv3': <tf.Tensor 'pnet_4/conv3/BiasAdd:0' shape=(None, None, None, 32) dtype=float32>, 'PReLU3': <tf.Tensor 'pnet_4/PReLU3/add:0' shape=(None, None, None, 32) dtype=float32>, 'conv4-1': <tf.Tensor 'pnet_4/conv4-1/BiasAdd:0' shape=(None, None, None, 2) dtype=float32>, 'prob1': <tf.Tensor 'pnet_4/prob1:0' shape=(None, None, None, 2) dtype=float32>, 'conv4-2': <tf.Tensor 'pnet_4/conv4-2/BiasAdd:0' shape=(None, None, None, 4) dtype=float32>} --after
# ----layer_decorated----
# Tensor("rnet_5/input:0", shape=(None, 24, 24, 3), dtype=float32) --input conv
# Tensor("rnet_5/conv1/BiasAdd:0", shape=(None, 22, 22, 28), dtype=float32) ---out conv
# {'data': <tf.Tensor 'rnet_5/input:0' shape=(None, 24, 24, 3) dtype=float32>, 'conv1': <tf.Tensor 'rnet_5/conv1/BiasAdd:0' shape=(None, 22, 22, 28) dtype=float32>} --after
# ----layer_decorated----
# Tensor("rnet_5/conv1/BiasAdd:0", shape=(None, 22, 22, 28), dtype=float32) ---input prelu
# Tensor("rnet_5/prelu1/add:0", shape=(None, 22, 22, 28), dtype=float32) ---out prelu
# {'data': <tf.Tensor 'rnet_5/input:0' shape=(None, 24, 24, 3) dtype=float32>, 'conv1': <tf.Tensor 'rnet_5/conv1/BiasAdd:0' shape=(None, 22, 22, 28) dtype=float32>, 'prelu1': <tf.Tensor 'rnet_5/prelu1/add:0' shape=(None, 22, 22, 28) dtype=float32>} --after
# ----layer_decorated----
# Tensor("rnet_5/prelu1/add:0", shape=(None, 22, 22, 28), dtype=float32) ---input maxpool
# Tensor("rnet_5/pool1:0", shape=(None, 11, 11, 28), dtype=float32) ---out maxpool
# {'data': <tf.Tensor 'rnet_5/input:0' shape=(None, 24, 24, 3) dtype=float32>, 'conv1': <tf.Tensor 'rnet_5/conv1/BiasAdd:0' shape=(None, 22, 22, 28) dtype=float32>, 'prelu1': <tf.Tensor 'rnet_5/prelu1/add:0' shape=(None, 22, 22, 28) dtype=float32>, 'pool1': <tf.Tensor 'rnet_5/pool1:0' shape=(None, 11, 11, 28) dtype=float32>} --after
# ----layer_decorated----
# Tensor("rnet_5/pool1:0", shape=(None, 11, 11, 28), dtype=float32) --input conv
# Tensor("rnet_5/conv2/BiasAdd:0", shape=(None, 9, 9, 48), dtype=float32) ---out conv
# {'data': <tf.Tensor 'rnet_5/input:0' shape=(None, 24, 24, 3) dtype=float32>, 'conv1': <tf.Tensor 'rnet_5/conv1/BiasAdd:0' shape=(None, 22, 22, 28) dtype=float32>, 'prelu1': <tf.Tensor 'rnet_5/prelu1/add:0' shape=(None, 22, 22, 28) dtype=float32>, 'pool1': <tf.Tensor 'rnet_5/pool1:0' shape=(None, 11, 11, 28) dtype=float32>, 'conv2': <tf.Tensor 'rnet_5/conv2/BiasAdd:0' shape=(None, 9, 9, 48) dtype=float32>} --after
# ----layer_decorated----
# Tensor("rnet_5/conv2/BiasAdd:0", shape=(None, 9, 9, 48), dtype=float32) ---input prelu
# Tensor("rnet_5/prelu2/add:0", shape=(None, 9, 9, 48), dtype=float32) ---out prelu
# {'data': <tf.Tensor 'rnet_5/input:0' shape=(None, 24, 24, 3) dtype=float32>, 'conv1': <tf.Tensor 'rnet_5/conv1/BiasAdd:0' shape=(None, 22, 22, 28) dtype=float32>, 'prelu1': <tf.Tensor 'rnet_5/prelu1/add:0' shape=(None, 22, 22, 28) dtype=float32>, 'pool1': <tf.Tensor 'rnet_5/pool1:0' shape=(None, 11, 11, 28) dtype=float32>, 'conv2': <tf.Tensor 'rnet_5/conv2/BiasAdd:0' shape=(None, 9, 9, 48) dtype=float32>, 'prelu2': <tf.Tensor 'rnet_5/prelu2/add:0' shape=(None, 9, 9, 48) dtype=float32>} --after
# ----layer_decorated----
# Tensor("rnet_5/prelu2/add:0", shape=(None, 9, 9, 48), dtype=float32) ---input maxpool
# Tensor("rnet_5/pool2:0", shape=(None, 4, 4, 48), dtype=float32) ---out maxpool
# {'data': <tf.Tensor 'rnet_5/input:0' shape=(None, 24, 24, 3) dtype=float32>, 'conv1': <tf.Tensor 'rnet_5/conv1/BiasAdd:0' shape=(None, 22, 22, 28) dtype=float32>, 'prelu1': <tf.Tensor 'rnet_5/prelu1/add:0' shape=(None, 22, 22, 28) dtype=float32>, 'pool1': <tf.Tensor 'rnet_5/pool1:0' shape=(None, 11, 11, 28) dtype=float32>, 'conv2': <tf.Tensor 'rnet_5/conv2/BiasAdd:0' shape=(None, 9, 9, 48) dtype=float32>, 'prelu2': <tf.Tensor 'rnet_5/prelu2/add:0' shape=(None, 9, 9, 48) dtype=float32>, 'pool2': <tf.Tensor 'rnet_5/pool2:0' shape=(None, 4, 4, 48) dtype=float32>} --after
# ----layer_decorated----
# Tensor("rnet_5/pool2:0", shape=(None, 4, 4, 48), dtype=float32) --input conv
# Tensor("rnet_5/conv3/BiasAdd:0", shape=(None, 3, 3, 64), dtype=float32) ---out conv
# {'data': <tf.Tensor 'rnet_5/input:0' shape=(None, 24, 24, 3) dtype=float32>, 'conv1': <tf.Tensor 'rnet_5/conv1/BiasAdd:0' shape=(None, 22, 22, 28) dtype=float32>, 'prelu1': <tf.Tensor 'rnet_5/prelu1/add:0' shape=(None, 22, 22, 28) dtype=float32>, 'pool1': <tf.Tensor 'rnet_5/pool1:0' shape=(None, 11, 11, 28) dtype=float32>, 'conv2': <tf.Tensor 'rnet_5/conv2/BiasAdd:0' shape=(None, 9, 9, 48) dtype=float32>, 'prelu2': <tf.Tensor 'rnet_5/prelu2/add:0' shape=(None, 9, 9, 48) dtype=float32>, 'pool2': <tf.Tensor 'rnet_5/pool2:0' shape=(None, 4, 4, 48) dtype=float32>, 'conv3': <tf.Tensor 'rnet_5/conv3/BiasAdd:0' shape=(None, 3, 3, 64) dtype=float32>} --after
# ----layer_decorated----
# Tensor("rnet_5/conv3/BiasAdd:0", shape=(None, 3, 3, 64), dtype=float32) ---input prelu
# Tensor("rnet_5/prelu3/add:0", shape=(None, 3, 3, 64), dtype=float32) ---out prelu
# {'data': <tf.Tensor 'rnet_5/input:0' shape=(None, 24, 24, 3) dtype=float32>, 'conv1': <tf.Tensor 'rnet_5/conv1/BiasAdd:0' shape=(None, 22, 22, 28) dtype=float32>, 'prelu1': <tf.Tensor 'rnet_5/prelu1/add:0' shape=(None, 22, 22, 28) dtype=float32>, 'pool1': <tf.Tensor 'rnet_5/pool1:0' shape=(None, 11, 11, 28) dtype=float32>, 'conv2': <tf.Tensor 'rnet_5/conv2/BiasAdd:0' shape=(None, 9, 9, 48) dtype=float32>, 'prelu2': <tf.Tensor 'rnet_5/prelu2/add:0' shape=(None, 9, 9, 48) dtype=float32>, 'pool2': <tf.Tensor 'rnet_5/pool2:0' shape=(None, 4, 4, 48) dtype=float32>, 'conv3': <tf.Tensor 'rnet_5/conv3/BiasAdd:0' shape=(None, 3, 3, 64) dtype=float32>, 'prelu3': <tf.Tensor 'rnet_5/prelu3/add:0' shape=(None, 3, 3, 64) dtype=float32>} --after
# ----layer_decorated----
# {'data': <tf.Tensor 'rnet_5/input:0' shape=(None, 24, 24, 3) dtype=float32>, 'conv1': <tf.Tensor 'rnet_5/conv1/BiasAdd:0' shape=(None, 22, 22, 28) dtype=float32>, 'prelu1': <tf.Tensor 'rnet_5/prelu1/add:0' shape=(None, 22, 22, 28) dtype=float32>, 'pool1': <tf.Tensor 'rnet_5/pool1:0' shape=(None, 11, 11, 28) dtype=float32>, 'conv2': <tf.Tensor 'rnet_5/conv2/BiasAdd:0' shape=(None, 9, 9, 48) dtype=float32>, 'prelu2': <tf.Tensor 'rnet_5/prelu2/add:0' shape=(None, 9, 9, 48) dtype=float32>, 'pool2': <tf.Tensor 'rnet_5/pool2:0' shape=(None, 4, 4, 48) dtype=float32>, 'conv3': <tf.Tensor 'rnet_5/conv3/BiasAdd:0' shape=(None, 3, 3, 64) dtype=float32>, 'prelu3': <tf.Tensor 'rnet_5/prelu3/add:0' shape=(None, 3, 3, 64) dtype=float32>, 'conv4': <tf.Tensor 'rnet_5/conv4/conv4:0' shape=(None, 128) dtype=float32>} --after
# ----layer_decorated----
# Tensor("rnet_5/conv4/conv4:0", shape=(None, 128), dtype=float32) ---input prelu
# Tensor("rnet_5/prelu4/add:0", shape=(None, 128), dtype=float32) ---out prelu
# {'data': <tf.Tensor 'rnet_5/input:0' shape=(None, 24, 24, 3) dtype=float32>, 'conv1': <tf.Tensor 'rnet_5/conv1/BiasAdd:0' shape=(None, 22, 22, 28) dtype=float32>, 'prelu1': <tf.Tensor 'rnet_5/prelu1/add:0' shape=(None, 22, 22, 28) dtype=float32>, 'pool1': <tf.Tensor 'rnet_5/pool1:0' shape=(None, 11, 11, 28) dtype=float32>, 'conv2': <tf.Tensor 'rnet_5/conv2/BiasAdd:0' shape=(None, 9, 9, 48) dtype=float32>, 'prelu2': <tf.Tensor 'rnet_5/prelu2/add:0' shape=(None, 9, 9, 48) dtype=float32>, 'pool2': <tf.Tensor 'rnet_5/pool2:0' shape=(None, 4, 4, 48) dtype=float32>, 'conv3': <tf.Tensor 'rnet_5/conv3/BiasAdd:0' shape=(None, 3, 3, 64) dtype=float32>, 'prelu3': <tf.Tensor 'rnet_5/prelu3/add:0' shape=(None, 3, 3, 64) dtype=float32>, 'conv4': <tf.Tensor 'rnet_5/conv4/conv4:0' shape=(None, 128) dtype=float32>, 'prelu4': <tf.Tensor 'rnet_5/prelu4/add:0' shape=(None, 128) dtype=float32>} --after
# ----layer_decorated----
# {'data': <tf.Tensor 'rnet_5/input:0' shape=(None, 24, 24, 3) dtype=float32>, 'conv1': <tf.Tensor 'rnet_5/conv1/BiasAdd:0' shape=(None, 22, 22, 28) dtype=float32>, 'prelu1': <tf.Tensor 'rnet_5/prelu1/add:0' shape=(None, 22, 22, 28) dtype=float32>, 'pool1': <tf.Tensor 'rnet_5/pool1:0' shape=(None, 11, 11, 28) dtype=float32>, 'conv2': <tf.Tensor 'rnet_5/conv2/BiasAdd:0' shape=(None, 9, 9, 48) dtype=float32>, 'prelu2': <tf.Tensor 'rnet_5/prelu2/add:0' shape=(None, 9, 9, 48) dtype=float32>, 'pool2': <tf.Tensor 'rnet_5/pool2:0' shape=(None, 4, 4, 48) dtype=float32>, 'conv3': <tf.Tensor 'rnet_5/conv3/BiasAdd:0' shape=(None, 3, 3, 64) dtype=float32>, 'prelu3': <tf.Tensor 'rnet_5/prelu3/add:0' shape=(None, 3, 3, 64) dtype=float32>, 'conv4': <tf.Tensor 'rnet_5/conv4/conv4:0' shape=(None, 128) dtype=float32>, 'prelu4': <tf.Tensor 'rnet_5/prelu4/add:0' shape=(None, 128) dtype=float32>, 'conv5-1': <tf.Tensor 'rnet_5/conv5-1/conv5-1:0' shape=(None, 2) dtype=float32>} --after
# ----layer_decorated----
# Tensor("rnet_5/conv5-1/conv5-1:0", shape=(None, 2), dtype=float32) ---target softmax
# Tensor("rnet_5/prob1:0", shape=(None, 2), dtype=float32) ---out softmax
# {'data': <tf.Tensor 'rnet_5/input:0' shape=(None, 24, 24, 3) dtype=float32>, 'conv1': <tf.Tensor 'rnet_5/conv1/BiasAdd:0' shape=(None, 22, 22, 28) dtype=float32>, 'prelu1': <tf.Tensor 'rnet_5/prelu1/add:0' shape=(None, 22, 22, 28) dtype=float32>, 'pool1': <tf.Tensor 'rnet_5/pool1:0' shape=(None, 11, 11, 28) dtype=float32>, 'conv2': <tf.Tensor 'rnet_5/conv2/BiasAdd:0' shape=(None, 9, 9, 48) dtype=float32>, 'prelu2': <tf.Tensor 'rnet_5/prelu2/add:0' shape=(None, 9, 9, 48) dtype=float32>, 'pool2': <tf.Tensor 'rnet_5/pool2:0' shape=(None, 4, 4, 48) dtype=float32>, 'conv3': <tf.Tensor 'rnet_5/conv3/BiasAdd:0' shape=(None, 3, 3, 64) dtype=float32>, 'prelu3': <tf.Tensor 'rnet_5/prelu3/add:0' shape=(None, 3, 3, 64) dtype=float32>, 'conv4': <tf.Tensor 'rnet_5/conv4/conv4:0' shape=(None, 128) dtype=float32>, 'prelu4': <tf.Tensor 'rnet_5/prelu4/add:0' shape=(None, 128) dtype=float32>, 'conv5-1': <tf.Tensor 'rnet_5/conv5-1/conv5-1:0' shape=(None, 2) dtype=float32>, 'prob1': <tf.Tensor 'rnet_5/prob1:0' shape=(None, 2) dtype=float32>} --after
# ----layer_decorated----
# {'data': <tf.Tensor 'rnet_5/input:0' shape=(None, 24, 24, 3) dtype=float32>, 'conv1': <tf.Tensor 'rnet_5/conv1/BiasAdd:0' shape=(None, 22, 22, 28) dtype=float32>, 'prelu1': <tf.Tensor 'rnet_5/prelu1/add:0' shape=(None, 22, 22, 28) dtype=float32>, 'pool1': <tf.Tensor 'rnet_5/pool1:0' shape=(None, 11, 11, 28) dtype=float32>, 'conv2': <tf.Tensor 'rnet_5/conv2/BiasAdd:0' shape=(None, 9, 9, 48) dtype=float32>, 'prelu2': <tf.Tensor 'rnet_5/prelu2/add:0' shape=(None, 9, 9, 48) dtype=float32>, 'pool2': <tf.Tensor 'rnet_5/pool2:0' shape=(None, 4, 4, 48) dtype=float32>, 'conv3': <tf.Tensor 'rnet_5/conv3/BiasAdd:0' shape=(None, 3, 3, 64) dtype=float32>, 'prelu3': <tf.Tensor 'rnet_5/prelu3/add:0' shape=(None, 3, 3, 64) dtype=float32>, 'conv4': <tf.Tensor 'rnet_5/conv4/conv4:0' shape=(None, 128) dtype=float32>, 'prelu4': <tf.Tensor 'rnet_5/prelu4/add:0' shape=(None, 128) dtype=float32>, 'conv5-1': <tf.Tensor 'rnet_5/conv5-1/conv5-1:0' shape=(None, 2) dtype=float32>, 'prob1': <tf.Tensor 'rnet_5/prob1:0' shape=(None, 2) dtype=float32>, 'conv5-2': <tf.Tensor 'rnet_5/conv5-2/conv5-2:0' shape=(None, 4) dtype=float32>} --after
# ----layer_decorated----
# Tensor("onet_5/input:0", shape=(None, 48, 48, 3), dtype=float32) --input conv
# Tensor("onet_5/conv1/BiasAdd:0", shape=(None, 46, 46, 32), dtype=float32) ---out conv
# {'data': <tf.Tensor 'onet_5/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet_5/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>} --after
# ----layer_decorated----
# Tensor("onet_5/conv1/BiasAdd:0", shape=(None, 46, 46, 32), dtype=float32) ---input prelu
# Tensor("onet_5/prelu1/add:0", shape=(None, 46, 46, 32), dtype=float32) ---out prelu
# {'data': <tf.Tensor 'onet_5/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet_5/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet_5/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>} --after
# ----layer_decorated----
# Tensor("onet_5/prelu1/add:0", shape=(None, 46, 46, 32), dtype=float32) ---input maxpool
# Tensor("onet_5/pool1:0", shape=(None, 23, 23, 32), dtype=float32) ---out maxpool
# {'data': <tf.Tensor 'onet_5/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet_5/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet_5/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet_5/pool1:0' shape=(None, 23, 23, 32) dtype=float32>} --after
# ----layer_decorated----
# Tensor("onet_5/pool1:0", shape=(None, 23, 23, 32), dtype=float32) --input conv
# Tensor("onet_5/conv2/BiasAdd:0", shape=(None, 21, 21, 64), dtype=float32) ---out conv
# {'data': <tf.Tensor 'onet_5/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet_5/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet_5/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet_5/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet_5/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>} --after
# ----layer_decorated----
# Tensor("onet_5/conv2/BiasAdd:0", shape=(None, 21, 21, 64), dtype=float32) ---input prelu
# Tensor("onet_5/prelu2/add:0", shape=(None, 21, 21, 64), dtype=float32) ---out prelu
# {'data': <tf.Tensor 'onet_5/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet_5/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet_5/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet_5/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet_5/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>, 'prelu2': <tf.Tensor 'onet_5/prelu2/add:0' shape=(None, 21, 21, 64) dtype=float32>} --after
# ----layer_decorated----
# Tensor("onet_5/prelu2/add:0", shape=(None, 21, 21, 64), dtype=float32) ---input maxpool
# Tensor("onet_5/pool2:0", shape=(None, 10, 10, 64), dtype=float32) ---out maxpool
# {'data': <tf.Tensor 'onet_5/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet_5/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet_5/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet_5/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet_5/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>, 'prelu2': <tf.Tensor 'onet_5/prelu2/add:0' shape=(None, 21, 21, 64) dtype=float32>, 'pool2': <tf.Tensor 'onet_5/pool2:0' shape=(None, 10, 10, 64) dtype=float32>} --after
# ----layer_decorated----
# Tensor("onet_5/pool2:0", shape=(None, 10, 10, 64), dtype=float32) --input conv
# Tensor("onet_5/conv3/BiasAdd:0", shape=(None, 8, 8, 64), dtype=float32) ---out conv
# {'data': <tf.Tensor 'onet_5/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet_5/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet_5/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet_5/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet_5/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>, 'prelu2': <tf.Tensor 'onet_5/prelu2/add:0' shape=(None, 21, 21, 64) dtype=float32>, 'pool2': <tf.Tensor 'onet_5/pool2:0' shape=(None, 10, 10, 64) dtype=float32>, 'conv3': <tf.Tensor 'onet_5/conv3/BiasAdd:0' shape=(None, 8, 8, 64) dtype=float32>} --after
# ----layer_decorated----
# Tensor("onet_5/conv3/BiasAdd:0", shape=(None, 8, 8, 64), dtype=float32) ---input prelu
# Tensor("onet_5/prelu3/add:0", shape=(None, 8, 8, 64), dtype=float32) ---out prelu
# {'data': <tf.Tensor 'onet_5/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet_5/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet_5/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet_5/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet_5/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>, 'prelu2': <tf.Tensor 'onet_5/prelu2/add:0' shape=(None, 21, 21, 64) dtype=float32>, 'pool2': <tf.Tensor 'onet_5/pool2:0' shape=(None, 10, 10, 64) dtype=float32>, 'conv3': <tf.Tensor 'onet_5/conv3/BiasAdd:0' shape=(None, 8, 8, 64) dtype=float32>, 'prelu3': <tf.Tensor 'onet_5/prelu3/add:0' shape=(None, 8, 8, 64) dtype=float32>} --after
# ----layer_decorated----
# Tensor("onet_5/prelu3/add:0", shape=(None, 8, 8, 64), dtype=float32) ---input maxpool
# Tensor("onet_5/pool3:0", shape=(None, 4, 4, 64), dtype=float32) ---out maxpool
# {'data': <tf.Tensor 'onet_5/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet_5/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet_5/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet_5/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet_5/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>, 'prelu2': <tf.Tensor 'onet_5/prelu2/add:0' shape=(None, 21, 21, 64) dtype=float32>, 'pool2': <tf.Tensor 'onet_5/pool2:0' shape=(None, 10, 10, 64) dtype=float32>, 'conv3': <tf.Tensor 'onet_5/conv3/BiasAdd:0' shape=(None, 8, 8, 64) dtype=float32>, 'prelu3': <tf.Tensor 'onet_5/prelu3/add:0' shape=(None, 8, 8, 64) dtype=float32>, 'pool3': <tf.Tensor 'onet_5/pool3:0' shape=(None, 4, 4, 64) dtype=float32>} --after
# ----layer_decorated----
# Tensor("onet_5/pool3:0", shape=(None, 4, 4, 64), dtype=float32) --input conv
# Tensor("onet_5/conv4/BiasAdd:0", shape=(None, 3, 3, 128), dtype=float32) ---out conv
# {'data': <tf.Tensor 'onet_5/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet_5/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet_5/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet_5/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet_5/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>, 'prelu2': <tf.Tensor 'onet_5/prelu2/add:0' shape=(None, 21, 21, 64) dtype=float32>, 'pool2': <tf.Tensor 'onet_5/pool2:0' shape=(None, 10, 10, 64) dtype=float32>, 'conv3': <tf.Tensor 'onet_5/conv3/BiasAdd:0' shape=(None, 8, 8, 64) dtype=float32>, 'prelu3': <tf.Tensor 'onet_5/prelu3/add:0' shape=(None, 8, 8, 64) dtype=float32>, 'pool3': <tf.Tensor 'onet_5/pool3:0' shape=(None, 4, 4, 64) dtype=float32>, 'conv4': <tf.Tensor 'onet_5/conv4/BiasAdd:0' shape=(None, 3, 3, 128) dtype=float32>} --after
# ----layer_decorated----
# Tensor("onet_5/conv4/BiasAdd:0", shape=(None, 3, 3, 128), dtype=float32) ---input prelu
# Tensor("onet_5/prelu4/add:0", shape=(None, 3, 3, 128), dtype=float32) ---out prelu
# {'data': <tf.Tensor 'onet_5/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet_5/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet_5/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet_5/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet_5/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>, 'prelu2': <tf.Tensor 'onet_5/prelu2/add:0' shape=(None, 21, 21, 64) dtype=float32>, 'pool2': <tf.Tensor 'onet_5/pool2:0' shape=(None, 10, 10, 64) dtype=float32>, 'conv3': <tf.Tensor 'onet_5/conv3/BiasAdd:0' shape=(None, 8, 8, 64) dtype=float32>, 'prelu3': <tf.Tensor 'onet_5/prelu3/add:0' shape=(None, 8, 8, 64) dtype=float32>, 'pool3': <tf.Tensor 'onet_5/pool3:0' shape=(None, 4, 4, 64) dtype=float32>, 'conv4': <tf.Tensor 'onet_5/conv4/BiasAdd:0' shape=(None, 3, 3, 128) dtype=float32>, 'prelu4': <tf.Tensor 'onet_5/prelu4/add:0' shape=(None, 3, 3, 128) dtype=float32>} --after
# ----layer_decorated----
# {'data': <tf.Tensor 'onet_5/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet_5/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet_5/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet_5/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet_5/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>, 'prelu2': <tf.Tensor 'onet_5/prelu2/add:0' shape=(None, 21, 21, 64) dtype=float32>, 'pool2': <tf.Tensor 'onet_5/pool2:0' shape=(None, 10, 10, 64) dtype=float32>, 'conv3': <tf.Tensor 'onet_5/conv3/BiasAdd:0' shape=(None, 8, 8, 64) dtype=float32>, 'prelu3': <tf.Tensor 'onet_5/prelu3/add:0' shape=(None, 8, 8, 64) dtype=float32>, 'pool3': <tf.Tensor 'onet_5/pool3:0' shape=(None, 4, 4, 64) dtype=float32>, 'conv4': <tf.Tensor 'onet_5/conv4/BiasAdd:0' shape=(None, 3, 3, 128) dtype=float32>, 'prelu4': <tf.Tensor 'onet_5/prelu4/add:0' shape=(None, 3, 3, 128) dtype=float32>, 'conv5': <tf.Tensor 'onet_5/conv5/conv5:0' shape=(None, 256) dtype=float32>} --after
# ----layer_decorated----
# Tensor("onet_5/conv5/conv5:0", shape=(None, 256), dtype=float32) ---input prelu
# Tensor("onet_5/prelu5/add:0", shape=(None, 256), dtype=float32) ---out prelu
# {'data': <tf.Tensor 'onet_5/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet_5/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet_5/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet_5/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet_5/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>, 'prelu2': <tf.Tensor 'onet_5/prelu2/add:0' shape=(None, 21, 21, 64) dtype=float32>, 'pool2': <tf.Tensor 'onet_5/pool2:0' shape=(None, 10, 10, 64) dtype=float32>, 'conv3': <tf.Tensor 'onet_5/conv3/BiasAdd:0' shape=(None, 8, 8, 64) dtype=float32>, 'prelu3': <tf.Tensor 'onet_5/prelu3/add:0' shape=(None, 8, 8, 64) dtype=float32>, 'pool3': <tf.Tensor 'onet_5/pool3:0' shape=(None, 4, 4, 64) dtype=float32>, 'conv4': <tf.Tensor 'onet_5/conv4/BiasAdd:0' shape=(None, 3, 3, 128) dtype=float32>, 'prelu4': <tf.Tensor 'onet_5/prelu4/add:0' shape=(None, 3, 3, 128) dtype=float32>, 'conv5': <tf.Tensor 'onet_5/conv5/conv5:0' shape=(None, 256) dtype=float32>, 'prelu5': <tf.Tensor 'onet_5/prelu5/add:0' shape=(None, 256) dtype=float32>} --after
# ----layer_decorated----
# {'data': <tf.Tensor 'onet_5/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet_5/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet_5/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet_5/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet_5/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>, 'prelu2': <tf.Tensor 'onet_5/prelu2/add:0' shape=(None, 21, 21, 64) dtype=float32>, 'pool2': <tf.Tensor 'onet_5/pool2:0' shape=(None, 10, 10, 64) dtype=float32>, 'conv3': <tf.Tensor 'onet_5/conv3/BiasAdd:0' shape=(None, 8, 8, 64) dtype=float32>, 'prelu3': <tf.Tensor 'onet_5/prelu3/add:0' shape=(None, 8, 8, 64) dtype=float32>, 'pool3': <tf.Tensor 'onet_5/pool3:0' shape=(None, 4, 4, 64) dtype=float32>, 'conv4': <tf.Tensor 'onet_5/conv4/BiasAdd:0' shape=(None, 3, 3, 128) dtype=float32>, 'prelu4': <tf.Tensor 'onet_5/prelu4/add:0' shape=(None, 3, 3, 128) dtype=float32>, 'conv5': <tf.Tensor 'onet_5/conv5/conv5:0' shape=(None, 256) dtype=float32>, 'prelu5': <tf.Tensor 'onet_5/prelu5/add:0' shape=(None, 256) dtype=float32>, 'conv6-1': <tf.Tensor 'onet_5/conv6-1/conv6-1:0' shape=(None, 2) dtype=float32>} --after
# ----layer_decorated----
# Tensor("onet_5/conv6-1/conv6-1:0", shape=(None, 2), dtype=float32) ---target softmax
# Tensor("onet_5/prob1:0", shape=(None, 2), dtype=float32) ---out softmax
# {'data': <tf.Tensor 'onet_5/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet_5/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet_5/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet_5/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet_5/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>, 'prelu2': <tf.Tensor 'onet_5/prelu2/add:0' shape=(None, 21, 21, 64) dtype=float32>, 'pool2': <tf.Tensor 'onet_5/pool2:0' shape=(None, 10, 10, 64) dtype=float32>, 'conv3': <tf.Tensor 'onet_5/conv3/BiasAdd:0' shape=(None, 8, 8, 64) dtype=float32>, 'prelu3': <tf.Tensor 'onet_5/prelu3/add:0' shape=(None, 8, 8, 64) dtype=float32>, 'pool3': <tf.Tensor 'onet_5/pool3:0' shape=(None, 4, 4, 64) dtype=float32>, 'conv4': <tf.Tensor 'onet_5/conv4/BiasAdd:0' shape=(None, 3, 3, 128) dtype=float32>, 'prelu4': <tf.Tensor 'onet_5/prelu4/add:0' shape=(None, 3, 3, 128) dtype=float32>, 'conv5': <tf.Tensor 'onet_5/conv5/conv5:0' shape=(None, 256) dtype=float32>, 'prelu5': <tf.Tensor 'onet_5/prelu5/add:0' shape=(None, 256) dtype=float32>, 'conv6-1': <tf.Tensor 'onet_5/conv6-1/conv6-1:0' shape=(None, 2) dtype=float32>, 'prob1': <tf.Tensor 'onet_5/prob1:0' shape=(None, 2) dtype=float32>} --after
# ----layer_decorated----
# {'data': <tf.Tensor 'onet_5/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet_5/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet_5/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet_5/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet_5/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>, 'prelu2': <tf.Tensor 'onet_5/prelu2/add:0' shape=(None, 21, 21, 64) dtype=float32>, 'pool2': <tf.Tensor 'onet_5/pool2:0' shape=(None, 10, 10, 64) dtype=float32>, 'conv3': <tf.Tensor 'onet_5/conv3/BiasAdd:0' shape=(None, 8, 8, 64) dtype=float32>, 'prelu3': <tf.Tensor 'onet_5/prelu3/add:0' shape=(None, 8, 8, 64) dtype=float32>, 'pool3': <tf.Tensor 'onet_5/pool3:0' shape=(None, 4, 4, 64) dtype=float32>, 'conv4': <tf.Tensor 'onet_5/conv4/BiasAdd:0' shape=(None, 3, 3, 128) dtype=float32>, 'prelu4': <tf.Tensor 'onet_5/prelu4/add:0' shape=(None, 3, 3, 128) dtype=float32>, 'conv5': <tf.Tensor 'onet_5/conv5/conv5:0' shape=(None, 256) dtype=float32>, 'prelu5': <tf.Tensor 'onet_5/prelu5/add:0' shape=(None, 256) dtype=float32>, 'conv6-1': <tf.Tensor 'onet_5/conv6-1/conv6-1:0' shape=(None, 2) dtype=float32>, 'prob1': <tf.Tensor 'onet_5/prob1:0' shape=(None, 2) dtype=float32>, 'conv6-2': <tf.Tensor 'onet_5/conv6-2/conv6-2:0' shape=(None, 4) dtype=float32>} --after
# ----layer_decorated----
# {'data': <tf.Tensor 'onet_5/input:0' shape=(None, 48, 48, 3) dtype=float32>, 'conv1': <tf.Tensor 'onet_5/conv1/BiasAdd:0' shape=(None, 46, 46, 32) dtype=float32>, 'prelu1': <tf.Tensor 'onet_5/prelu1/add:0' shape=(None, 46, 46, 32) dtype=float32>, 'pool1': <tf.Tensor 'onet_5/pool1:0' shape=(None, 23, 23, 32) dtype=float32>, 'conv2': <tf.Tensor 'onet_5/conv2/BiasAdd:0' shape=(None, 21, 21, 64) dtype=float32>, 'prelu2': <tf.Tensor 'onet_5/prelu2/add:0' shape=(None, 21, 21, 64) dtype=float32>, 'pool2': <tf.Tensor 'onet_5/pool2:0' shape=(None, 10, 10, 64) dtype=float32>, 'conv3': <tf.Tensor 'onet_5/conv3/BiasAdd:0' shape=(None, 8, 8, 64) dtype=float32>, 'prelu3': <tf.Tensor 'onet_5/prelu3/add:0' shape=(None, 8, 8, 64) dtype=float32>, 'pool3': <tf.Tensor 'onet_5/pool3:0' shape=(None, 4, 4, 64) dtype=float32>, 'conv4': <tf.Tensor 'onet_5/conv4/BiasAdd:0' shape=(None, 3, 3, 128) dtype=float32>, 'prelu4': <tf.Tensor 'onet_5/prelu4/add:0' shape=(None, 3, 3, 128) dtype=float32>, 'conv5': <tf.Tensor 'onet_5/conv5/conv5:0' shape=(None, 256) dtype=float32>, 'prelu5': <tf.Tensor 'onet_5/prelu5/add:0' shape=(None, 256) dtype=float32>, 'conv6-1': <tf.Tensor 'onet_5/conv6-1/conv6-1:0' shape=(None, 2) dtype=float32>, 'prob1': <tf.Tensor 'onet_5/prob1:0' shape=(None, 2) dtype=float32>, 'conv6-2': <tf.Tensor 'onet_5/conv6-2/conv6-2:0' shape=(None, 4) dtype=float32>, 'conv6-3': <tf.Tensor 'onet_5/conv6-3/conv6-3:0' shape=(None, 10) dtype=float32>} --after
# ----layer_decorated----

# %%
print(left_eye_im_desc , left_eye_im_diagnosis)
plt.imshow(left_eye_im)
plt.show()
print(right_eye_im_desc , right_eye_im_diagnosis)
plt.imshow(right_eye_im)

plt.show()

plt.imshow(image)
# Out:
# no face detected no face detected
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-1803a9959999> in <module>
#       1 print(left_eye_im_desc , left_eye_im_diagnosis)
# ----> 2 plt.imshow(left_eye_im)
#       3 plt.show()
#       4 print(right_eye_im_desc , right_eye_im_diagnosis)
#       5 plt.imshow(right_eye_im)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2722         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2723         data=None, **kwargs):
# -> 2724     __ret = gca().imshow(
#    2725         X, cmap=cmap, norm=norm, aspect=aspect,
#    2726         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~/.local/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5521                               resample=resample, **kwargs)
#    5522
# -> 5523         im.set_data(X)
#    5524         im.set_alpha(alpha)
#    5525         if im.get_clip_path() is None:
#
# ~/.local/lib/python3.8/site-packages/matplotlib/image.py in set_data(self, A)
#     700         if (self._A.dtype != np.uint8 and
#     701                 not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 702             raise TypeError("Image data of dtype {} cannot be converted to "
#     703                             "float".format(self._A.dtype))
#     704
#
# TypeError: Image data of dtype <U16 cannot be converted to float

# %%
model.summary()

# %%
ls
# Out:
# '7 - dr. Meiliana Lay.jpeg'  'MicrosoftTeams-image (1).jpg'
#  cat.jpg                      models/
#  CroppingModels.ipynb         mtcnn_detect_face.py
#  detector/                    mtcnn_weights/
#  elg_weights/                 no_face.jpg
#  EyesCropping2.ipynb          __pycache__/
#  EyesCropping.ipynb           sunglasses_no_sunglasses.jpg
#  faace.jpg                    sunnglasses.jpg
#  fuzzyfaces.jpg               unhealthy.jpg
#  image.jpeg

# %%
diagnosis_model_path = '/home/khaldoun/Desktop/TOV_DataAcquisition/saved_models/Final_models/accuracy-92size100x100_Threshold_0.56.h5'
model = load_model(diagnosis_model_path)
img_path = 'MicrosoftTeams-image (1).jpg'
left_eye_im = cv2.imread(img_path)[..., ::-1]
plt.imshow(left_eye_im)

# %%
left_eye_im = cv2.resize(left_eye_im , (100, 100))
left_eye_im = left_eye_im.reshape(1 ,100 , 100 , -1)
model.predict(left_eye_im)
# Out:
# array([[0.06232017]], dtype=float32)
