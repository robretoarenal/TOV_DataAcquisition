# %%
import cv2
from matplotlib import pyplot as plt
from detector.face_detector import fd_pipeline

# %%
img_path = "images/rob.jpeg"
#img_path = "images/mop.jpg"
img = cv2.imread(img_path)[..., ::-1]
plt.imshow(img)

# %%
left_eye_im, right_eye_im = fd_pipeline(img)
# Out:
# WARNING:tensorflow:From /home/jovyan/work/detector/face_detector.py:177: The name tf.keras.backend.get_session is deprecated. Please use tf.compat.v1.keras.backend.get_session instead.
#
# WARNING:tensorflow:From /home/jovyan/work/mtcnn_detect_face.py:244: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.

# %%
plt.figure(figsize=(15,4))
plt.subplot(1,2,1)
plt.title("Left eye")
plt.imshow(left_eye_im)
plt.subplot(1,2,2)
plt.title("Right eye")
plt.imshow(right_eye_im)

# %%
img_path = "images/mop.jpg"
img = cv2.imread(img_path)[..., ::-1]
plt.imshow(img)

# %%
left_eye_im, right_eye_im = fd_pipeline(img)
# Out:
# AssertionErrorTraceback (most recent call last)
# <ipython-input-7-7dd537b2edc9> in <module>
# ----> 1 left_eye_im, right_eye_im = fd_pipeline(img)
#
# ~/work/detector/face_detector.py in fd_pipeline(img)
#     180         ])
#     181
# --> 182     lms = pipeline.fit_transform(img)
#     183     return lms
#
# /opt/conda/lib/python3.8/site-packages/sklearn/pipeline.py in fit_transform(self, X, y, **fit_params)
#     385             fit_params_last_step = fit_params_steps[self.steps[-1][0]]
#     386             if hasattr(last_step, 'fit_transform'):
# --> 387                 return last_step.fit_transform(Xt, y, **fit_params_last_step)
#     388             else:
#     389                 return last_step.fit(Xt, y,
#
# /opt/conda/lib/python3.8/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# ...
